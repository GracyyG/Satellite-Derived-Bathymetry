# %% [markdown]
# # Run SDB Pipeline
#
# This notebook runs the main SDB pipeline script (`main_pipeline.py`) and monitors its execution. It captures output, handles errors, and provides status updates throughout the process.

# %%
# Import required libraries
import os
import sys
import subprocess
from pathlib import Path
from datetime import datetime
from IPython.display import display, HTML

# Project setup
project_root = Path.cwd().parent
main_script = project_root / 'main_pipeline.py'
log_dir = project_root / 'logs'
log_dir.mkdir(parents=True, exist_ok=True)

print(f"Project root: {project_root}")
print(f"Main script: {main_script}")
print(f"Log directory: {log_dir}")
# Out:
# Project root: d:\Project\sdb_project
# Main script: d:\Project\sdb_project\main_pipeline.py
# Log directory: d:\Project\sdb_project\logs

# %% [markdown]
# ## Execute Pipeline
#
# Run the main pipeline script and capture its output in real-time.

# %%
# Get Python executable from environment
python_executable = sys.executable

# Run the pipeline
start_time = datetime.now()
print(f"Starting pipeline execution at {start_time.strftime('%Y-%m-%d %H:%M:%S')}")
print("-" * 60)

try:
    # Execute the pipeline with proper encoding
    env = os.environ.copy()
    env["PYTHONIOENCODING"] = "utf-8"
    
    result = subprocess.run(
        [python_executable, str(main_script)],
        capture_output=True,
        text=True,
        encoding='utf-8',
        errors='replace',
        env=env,
        cwd=str(project_root)
    )
    
    # Print output in real-time
    print("Output:")
    if result.stdout:
        print(result.stdout)
    
    if result.stderr:
        print("\nErrors:")
        print(result.stderr)
    
    # Calculate duration
    duration = datetime.now() - start_time
    
    # Print status
    if result.returncode == 0:
        print(f"\n✅ Pipeline completed successfully in {duration}")
    else:
        print(f"\n❌ Pipeline failed with exit code {result.returncode} after {duration}")
    
except Exception as e:
    print(f"\n❌ Error running pipeline: {str(e)}")
# Out:
# Starting pipeline execution at 2025-11-10 21:35:19
# ------------------------------------------------------------
# Output:
#
# ============================================================
# 🌍 Running SDB pipeline for region: Lakshadweep
# Area of Interest:
#   Latitude:  10.75° to 10.95°
#   Longitude: 72.35° to 72.65°
# ============================================================
#
# 2025-11-10 21:35:21,400 [INFO] ✅ Copernicus API credentials verified and loaded from sentinel_api_config.json
# 2025-11-10 21:35:21,400 [INFO] Starting notebook: 01_sentinel2_download.ipynb
# 🔄 Executing: 01_sentinel2_download.ipynb
# 2025-11-10 21:35:21,400 [INFO] Input Notebook:  d:\Project\sdb_project\notebooks\01_sentinel2_download.ipynb
# 2025-11-10 21:35:21,400 [INFO] Output Notebook: d:\Project\sdb_project\outputs\lakshadweep\executed_notebooks\01_sentinel2_download.ipynb
# 2025-11-10 21:35:21,432 [WARNING] Passed unknown parameter: region_name
# 2025-11-10 21:35:21,432 [WARNING] Passed unknown parameter: output_dir
# 2025-11-10 21:35:21,432 [WARNING] Input notebook does not contain a cell with tag 'parameters'
# 2025-11-10 21:35:23,400 [INFO] Executing notebook with kernel: python3
# 2025-11-10 21:35:24,677 [ERROR] ❌ 01_sentinel2_download.ipynb failed after 0:00:03.276208:
# ---------------------------------------------------------------------------
# Exception encountered at "In [2]":
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 1
#
#
# ❌ 01_sentinel2_download.ipynb failed - see logs for details
# 2025-11-10 21:35:24,677 [ERROR] Pipeline execution stopped due to error
#
#
# Errors:
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Python312\Lib\logging\__init__.py", line 1163, in emit
#     stream.write(msg + self.terminator)
#   File "C:\Python312\Lib\encodings\cp1252.py", line 19, in encode
#     return codecs.charmap_encode(input,self.errors,encoding_table)[0]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# UnicodeEncodeError: 'charmap' codec can't encode character '\u2705' in position 31: character maps to <undefined>
# Call stack:
#   File "d:\Project\sdb_project\main_pipeline.py", line 197, in <module>
#     main()
#   File "d:\Project\sdb_project\main_pipeline.py", line 187, in main
#     success = pipeline.run_pipeline()
#   File "d:\Project\sdb_project\main_pipeline.py", line 155, in run_pipeline
#     if not self.check_api_credentials():
#   File "d:\Project\sdb_project\main_pipeline.py", line 57, in check_api_credentials
#     self.logger.info("✅ Copernicus API credentials verified and loaded from sentinel_api_config.json")
# Message: '✅ Copernicus API credentials verified and loaded from sentinel_api_config.json'
# Arguments: ()
#
# Executing:   0%|          | 0/16 [00:00<?, ?cell/s]
# Executing:   6%|▋         | 1/16 [00:01<00:29,  1.96s/cell]
# Executing:  19%|█▉        | 3/16 [00:02<00:11,  1.18cell/s]
# Executing:  19%|█▉        | 3/16 [00:03<00:13,  1.07s/cell]
# --- Logging error ---
# Traceback (most recent call last):
#   File "d:\Project\sdb_project\main_pipeline.py", line 126, in execute_notebook
#     pm.execute_notebook(
#   File "d:\Project\.venv\Lib\site-packages\papermill\execute.py", line 131, in execute_notebook
#     raise_for_execution_errors(nb, output_path)
#   File "d:\Project\.venv\Lib\site-packages\papermill\execute.py", line 251, in raise_for_execution_errors
#     raise error
# papermill.exceptions.PapermillExecutionError:
# ---------------------------------------------------------------------------
# Exception encountered at "In [2]":
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 1
#
#
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Python312\Lib\logging\__init__.py", line 1163, in emit
#     stream.write(msg + self.terminator)
#   File "C:\Python312\Lib\encodings\cp1252.py", line 19, in encode
#     return codecs.charmap_encode(input,self.errors,encoding_table)[0]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# UnicodeEncodeError: 'charmap' codec can't encode character '\u274c' in position 32: character maps to <undefined>
# Call stack:
#   File "d:\Project\sdb_project\main_pipeline.py", line 197, in <module>
#     main()
#   File "d:\Project\sdb_project\main_pipeline.py", line 187, in main
#     success = pipeline.run_pipeline()
#   File "d:\Project\sdb_project\main_pipeline.py", line 160, in run_pipeline
#     if not self.execute_notebook(notebook):
#   File "d:\Project\sdb_project\main_pipeline.py", line 145, in execute_notebook
#     self.logger.error(f"❌ {notebook_name} failed after {duration}: {str(e)}")
# Message: '❌ 01_sentinel2_download.ipynb failed after 0:00:03.276208: \n---------------------------------------------------------------------------\nException encountered at "In [2]":\nAn exception has occurred, use %tb to see the full traceback.\n\nSystemExit: 1\n\n'
# Arguments: ()
#
#
# ❌ Pipeline failed with exit code 1 after 0:00:04.956408

# %% [markdown]
# ## Save Results
#
# Save the execution output and status to a log file for future reference.

# %%
# Save execution log
log_file = log_dir / f"pipeline_execution_{datetime.now().strftime('%Y%m%d_%H%M%S')}.log"

with open(log_file, 'w', encoding='utf-8') as f:
    f.write(f"Pipeline Execution Log\n")
    f.write(f"====================\n\n")
    f.write(f"Start Time: {start_time.strftime('%Y-%m-%d %H:%M:%S')}\n")
    f.write(f"Duration: {duration}\n")
    f.write(f"Exit Code: {result.returncode}\n\n")
    f.write("Output:\n")
    f.write("-------\n")
    if result.stdout:
        f.write(result.stdout)
    if result.stderr:
        f.write("\nErrors:\n")
        f.write("-------\n")
        f.write(result.stderr)

print(f"Log saved to: {log_file}")

# Display HTML summary
success = result.returncode == 0
html_summary = f"""
<div style="padding: 20px; border-radius: 5px; background-color: {'#e6ffe6' if success else '#ffe6e6'}">
    <h3 style="margin-top: 0">Pipeline Execution Summary</h3>
    <p><b>Status:</b> {'✅ Success' if success else '❌ Failed'}</p>
    <p><b>Duration:</b> {duration}</p>
    <p><b>Log File:</b> {log_file}</p>
</div>
"""
display(HTML(html_summary))
# Out:
# Log saved to: d:\Project\sdb_project\logs\pipeline_execution_20251110_213537.log
# <div style="padding: 20px; border-radius: 5px; background-color: #ffe6e6">
#     <h3 style="margin-top: 0">Pipeline Execution Summary</h3>
#     <p><b>Status:</b> ❌ Failed</p>
#     <p><b>Duration:</b> 0:00:04.956408</p>
#     <p><b>Log File:</b> d:\Project\sdb_project\logs\pipeline_execution_20251110_213537.log</p>
# </div>
